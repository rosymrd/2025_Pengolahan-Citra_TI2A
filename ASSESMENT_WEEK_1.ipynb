# %% [markdown]
# <a href="https://colab.research.google.com/github/rosymrd/2025_Pengolahan-Citra_TI2A/blob/main/ASSESMENT_WEEK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tugas 1: Menyimpan dan Menampilkan Data

# Menyimpan data
nama_produk1 = "Kopi Pagi"
harga_produk1 = 18000.5
nama_produk2 = "Roti Cokelat"
harga_produk2 = 10000
status_roti = True

# Menampilkan data
print("Nama produk 1:", nama_produk1)
print("Harga produk 1:", harga_produk1)
print("Nama produk 2:", nama_produk2)
print("Harga produk 2:", harga_produk2)
print("Status ketersediaan roti:", status_roti)
# Out:
# Nama produk 1: Kopi Pagi
# Harga produk 1: 18000.5
# Nama produk 2: Roti Cokelat
# Harga produk 2: 10000
# Status ketersediaan roti: True

# %%
# Tugas 2: Konversi Tipe Data dan Input Pengguna

# Meminta input dari pengguna
jumlah_kopi_str = input("Masukkan jumlah pesanan kopi: ")
jumlah_roti_str = input("Masukkan jumlah pesanan roti: ")

# Menampilkan tipe data awal
print("Tipe data awal jumlah kopi:", type(jumlah_kopi_str))
print("Tipe data awal jumlah roti:", type(jumlah_roti_str))

# Konversi ke integer
jumlah_kopi_int = int(jumlah_kopi_str)
jumlah_roti_int = int(jumlah_roti_str)

# Menampilkan tipe data setelah konversi
print("Tipe data setelah konversi jumlah kopi:", type(jumlah_kopi_int))
print("Tipe data setelah konversi jumlah roti:", type(jumlah_roti_int))
# Out:
# Masukkan jumlah pesanan kopi: 2
# Masukkan jumlah pesanan roti: 3
# Tipe data awal jumlah kopi: <class 'str'>
# Tipe data awal jumlah roti: <class 'str'>
# Tipe data setelah konversi jumlah kopi: <class 'int'>
# Tipe data setelah konversi jumlah roti: <class 'int'>

# %%
# Tugas 1: Data Produk
harga_kopi = 18000.5
harga_roti = 10000

# Tugas 2: Input Jumlah Pesanan
jumlah_kopi_str = input("Masukkan jumlah pesanan kopi: ")
jumlah_roti_str = input("Masukkan jumlah pesanan roti: ")

jumlah_kopi_int = int(jumlah_kopi_str)
jumlah_roti_int = int(jumlah_roti_str)

# Tugas 3: Operasi pada Angka
total_kopi = harga_kopi * jumlah_kopi_int
total_roti = harga_roti * jumlah_roti_int
total_belanja = total_kopi + total_roti

uang_bayar = 50000
kembalian = uang_bayar - total_belanja

# Cetak hasil
print("Total harga kopi:", total_kopi)
print("Total harga roti:", total_roti)
print("Total belanja keseluruhan:", total_belanja)
print("Uang yang dibayarkan:", uang_bayar)
print("Kembalian:", kembalian)
# Out:
# Masukkan jumlah pesanan kopi: 2
# Masukkan jumlah pesanan roti: 3
# Total harga kopi: 36001.0
# Total harga roti: 30000
# Total belanja keseluruhan: 66001.0
# Uang yang dibayarkan: 50000
# Kembalian: -16001.0

# %%
# Tugas 1: Data Produk
nama_produk1 = "Kopi Pagi"
harga_kopi = 18000.5
nama_produk2 = "Roti Cokelat"
harga_roti = 10000

# Tugas 2: Input Jumlah Pesanan
jumlah_kopi_str = input("Masukkan jumlah pesanan kopi: ")
jumlah_roti_str = input("Masukkan jumlah pesanan roti: ")

jumlah_kopi_int = int(jumlah_kopi_str)
jumlah_roti_int = int(jumlah_roti_str)

# Tugas 3: Operasi pada Angka
total_kopi = harga_kopi * jumlah_kopi_int
total_roti = harga_roti * jumlah_roti_int
total_belanja = total_kopi + total_roti

# Tugas 4: Operasi pada String
nama_pelanggan = input("Masukkan nama pelanggan: ")
pesan_terima_kasih = "Terima kasih, " + nama_pelanggan + " sudah berbelanja di Coffee Shop Bahagia!"
garis = "*" * 25

# Cetak Struk
print(garis)
print(pesan_terima_kasih)
print(garis)
print(f"Total harga {nama_produk1} adalah Rp{total_kopi}")
print(f"Total harga {nama_produk2} adalah Rp{total_roti}")
print(f"Total belanja keseluruhan: Rp{total_belanja}")
# Out:
# Masukkan jumlah pesanan kopi: 2
# Masukkan jumlah pesanan roti: 3
# Masukkan nama pelanggan: Mila Rosita Dewi
# *************************
# Terima kasih, Mila Rosita Dewi sudah berbelanja di Coffee Shop Bahagia!
# *************************
# Total harga Kopi Pagi adalah Rp36001.0
# Total harga Roti Cokelat adalah Rp30000
# Total belanja keseluruhan: Rp66001.0
